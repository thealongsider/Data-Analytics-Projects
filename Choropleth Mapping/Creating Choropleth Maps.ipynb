# %% [markdown]
# # Choropleth Map
# In this notebook, I will be practicing how to create choropleth maps using plotly.
# I will be plotting two different datasets provided by the "Python for data science and machine learning bootcamp" Udemy course.

# %% [markdown]
# To begin, we're going to import the necessay libraries to allow us to work with and see the plotly graphs in jupyter notebook

# %%
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# Next, we will import pandas and read our first dataset, 2014 World Power Consumption

# %%
import pandas as pd

# %%
dfwpc = pd.read_csv('2014_World_Power_Consumption')

# %%
dfwpc.head()
# Out:
#          Country  Power Consumption KWH                        Text
# 0          China           5.523000e+12     China 5,523,000,000,000
# 1  United States           3.832000e+12    United 3,832,000,000,000
# 2       European           2.771000e+12  European 2,771,000,000,000
# 3         Russia           1.065000e+12    Russia 1,065,000,000,000
# 4          Japan           9.210000e+11       Japan 921,000,000,000

# %% [markdown]
# We see that we have the power consumption by country and an accompanying descriptive text. Next, we'll create the data and layout dictionaries for plotly to read.

# %%
data = dict(type='choropleth',
           locations=dfwpc['Country'],
            locationmode = 'country names',
           z = dfwpc['Power Consumption KWH'],
           text = dfwpc['Text'],
           colorbar = {'title':'Power Consumption (KWH)'})

# %%
layout = dict(title = '2014 Global Power Consumption',
              geo = dict(showframe = False,
                        projection = {'type':'natural earth'}))

# %% [markdown]
# Now, we can use the data and layout we made and put it into a variable that plotly can read and read it

# %%
choromap1 = go.Figure(data = [data], layout = layout)
iplot(choromap1)
# Out:
# <div id="bde64ed0-76db-4923-b162-affd43f434d6" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("bde64ed0-76db-4923-b162-affd43f434d6", [{"colorbar": {"title": "Power Consumption (KWH)"}, "locationmode": "country names", "locations": ["China", "United States", "European", "Russia", "Japan", "India", "Germany", "Canada", "Brazil", "Korea,", "France", "United Kingdom", "Italy", "Taiwan", "Spain", "Mexico", "Saudi", "Australia", "South", "Turkey", "Iran", "Indonesia", "Ukraine", "Thailand", "Poland", "Egypt", "Sweden", "Norway", "Malaysia", "Argentina", "Netherlands", "Vietnam", "Venezuela", "United Arab Emirates", "Finland", "Belgium", "Kazakhstan", "Pakistan", "Philippines", "Austria", "Chile", "Czechia", "Israel", "Switzerland", "Greece", "Iraq", "Romania", "Kuwait", "Colombia", "Singapore", "Portugal", "Uzbekistan", "Hong", "Algeria", "Bangladesh", "New", "Bulgaria", "Belarus", "Peru", "Denmark", "Qatar", "Slovakia", "Libya", "Serbia", "Morocco", "Syria", "Nigeria", "Ireland", "Hungary", "Oman", "Ecuador", "Puerto", "Azerbaijan", "Croatia", "Iceland", "Cuba", "Korea,", "Dominican", "Jordan", "Tajikistan", "Tunisia", "Slovenia", "Lebanon", "Bosnia", "Turkmenistan", "Bahrain", "Mozambique", "Ghana", "Sri", "Kyrgyzstan", "Lithuania", "Uruguay", "Costa", "Guatemala", "Georgia", "Trinidad", "Zambia", "Paraguay", "Albania", "Burma", "Estonia", "Congo,", "Panama", "Latvia", "Macedonia", "Zimbabwe", "Kenya", "Bolivia", "Luxembourg", "Sudan", "El", "Cameroon", "West", "Ethiopia", "Armenia", "Honduras", "Angola", "Cote", "Tanzania", "Nicaragua", "Moldova", "Cyprus", "Macau", "Namibia", "Mongolia", "Afghanistan", "Yemen", "Brunei", "Cambodia", "Montenegro", "Nepal", "Botswana", "Papua", "Jamaica", "Kosovo", "Laos", "Uganda", "New", "Mauritius", "Senegal", "Bhutan", "Malawi", "Madagascar", "Bahamas,", "Gabon", "Suriname", "Guam", "Liechtenstein", "Swaziland", "Burkina", "Togo", "Curacao", "Mauritania", "Barbados", "Niger", "Aruba", "Benin", "Guinea", "Mali", "Fiji", "Congo,", "Virgin", "Lesotho", "South", "Bermuda", "French", "Jersey", "Belize", "Andorra", "Guyana", "Cayman", "Haiti", "Rwanda", "Saint", "Djibouti", "Seychelles", "Somalia", "Antigua", "Greenland", "Cabo", "Eritrea", "Burundi", "Liberia", "Maldives", "Faroe", "Gambia,", "Chad", "Micronesia,", "Grenada", "Central", "Turks", "Gibraltar", "American", "Sierra", "Saint", "Saint", "Timor-Leste", "Equatorial", "Samoa", "Dominica", "Western", "Solomon", "Sao", "British", "Vanuatu", "Guinea-Bissau", "Tonga", "Saint", "Comoros", "Cook", "Kiribati", "Montserrat", "Nauru", "Falkland", "Saint", "Niue", "Gaza", "Malta", "Northern"], "text": ["China 5,523,000,000,000", "United 3,832,000,000,000", "European 2,771,000,000,000", "Russia 1,065,000,000,000", "Japan 921,000,000,000", "India 864,700,000,000", "Germany 540,100,000,000", "Canada 511,000,000,000", "Brazil 483,500,000,000", "Korea, 482,400,000,000", "France 451,100,000,000", "United 319,100,000,000", "Italy 303,100,000,000", "Taiwan 249,500,000,000", "Spain 243,100,000,000", "Mexico 234,000,000,000", "Saudi 231,600,000,000", "Australia 222,600,000,000", "South 211,600,000,000", "Turkey 197,000,000,000", "Iran 195,300,000,000", "Indonesia 167,500,000,000", "Ukraine 159,800,000,000", "Thailand 155,900,000,000", "Poland 139,000,000,000", "Egypt 135,600,000,000", "Sweden 130,500,000,000", "Norway 126,400,000,000", "Malaysia 118,500,000,000", "Argentina 117,100,000,000", "Netherlands 116,800,000,000", "Vietnam 108,300,000,000", "Venezuela 97,690,000,000", "United 93,280,000,000", "Finland 82,040,000,000", "Belgium 81,890,000,000", "Kazakhstan 80,290,000,000", "Pakistan 78,890,000,000", "Philippines 75,270,000,000", "Austria 69,750,000,000", "Chile 63,390,000,000", "Czechia 60,550,000,000", "Israel 59,830,000,000", "Switzerland 58,010,000,000", "Greece 5 ...

# %% [markdown]
# The next data set we're going to utilize is data from the 2012 US Election

# %%
dfe = pd.read_csv('2012_Election_Data')

# %%
dfe.head()
# Out:
#    Year  ICPSR State Code  Alphanumeric State Code       State  \
# 0  2012                41                        1     Alabama
# 1  2012                81                        2      Alaska
# 2  2012                61                        3     Arizona
# 3  2012                42                        4    Arkansas
# 4  2012                71                        5  California
#
#   VEP Total Ballots Counted VEP Highest Office VAP Highest Office  \
# 0                       NaN              58.6%              56.0%
# 1                     58.9%              58.7%              55.3%
# 2                     53.0%              52.6%              46.5%
# 3                     51.1%              50.7%              47.7%
# 4                     55.7%              55.1%              45.1%
#
#   Total Ballots Counted Highest Office Voting-Eligible Population (VEP)  \
# 0                   NaN      2,074,338                        3,539,217
# 1               301,694        300,495                          511,792
# 2             2,323,579      2,306,559                        4,387,900
# 3             1,078,548      1,069,468                        2,109,847
# 4            13,202,158     13,038,547                       23,681,837
#
#    Voting-Age Population (VAP) % Non-citizen   Prison Probation  Parole  \
# 0                    3707440.0          2.6%   32,232    57,993   8,616
# 1                     543763.0          3.8%    5,633     7,173   1,882
# 2                    4959270.0          9.9%   35,188    72,452   7,460
# 3                    2242740.0          3.5%   14,471    30,122  23,372
# 4                   28913129.0         17.4%  119,455         0  89,287
#
#   Total Ineligible Felon State Abv
# 0                 71,584        AL
# 1                 11,317        AK
# 2                 81,048        AZ
# 3                 53,808        AR
# 4                208,742        CA

# %% [markdown]
# We notice that, unlike the previous dataset, there are many more columns of data available.

# %% [markdown]
# To begin with, let's create a choropleth map of the Voting-Age-Population (VAP) across the US by state

# %% [markdown]
# Like before, we need to create the data and layout for this choropleth map. This will become our template for using other variables later on

# %%
data = dict(type='choropleth',
           colorscale = 'YlOrRd',
            reversescale = True,
           locations = dfe['State Abv'],
           locationmode = 'USA-states',
           z = dfe['Voting-Age Population (VAP)'],
           colorbar = {'title':'Voting Age Population'}
           )

# %%
layout = dict(title = 'Voting Age Population by State',
             geo = dict(scope = 'usa',
                       showlakes = True,
                       lakecolor = 'rgb(85,173,240)')
             )

# %% [markdown]
# Now let's make our choropleth map

# %%
choromap2 = go.Figure(data = [data], layout = layout)
iplot(choromap2)
# Out:
# <div id="a6695bbb-4dd9-4ddf-bc39-1e521fc5eec2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a6695bbb-4dd9-4ddf-bc39-1e521fc5eec2", [{"colorbar": {"title": "Voting Age Population"}, "colorscale": "YlOrRd", "locationmode": "USA-states", "locations": ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "District of Columbia", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"], "reversescale": true, "z": [3707440.0, 543763.0, 4959270.0, 2242740.0, 28913129.0, 3981208.0, 2801375.0, 715708.0, 528848.0, 15380947.0, 7452696.0, 1088335.0, 1173727.0, 9827043.0, 4960376.0, 2356209.0, 2162442.0, 3368684.0, 3495847.0, 1064779.0, 4553853.0, 5263550.0, 7625576.0, 4114820.0, 2246931.0, 4628500.0, 785454.0, 1396507.0, 2105976.0, 1047978.0, 6847503.0, 1573400.0, 15344671.0, 7496980.0, 549955.0, 8896930.0, 2885093.0, 3050747.0, 10037099.0, 834983.0, 3662322.0, 631472.0, 4976284.0, 19185395.0, 1978956.0, 502242.0, 6348827.0, 5329782.0, 1472642.0, 4417273.0, 441726.0], "type": "choropleth", "uid": "640c63d8-5ec7-489c-b9c0-100206a18b87"}], {"geo": {"lakecolor": "rgb(85,173,240)", "scope": "usa", "showlakes": true}, "title": "Voting Age Population by State"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("a6695bbb-4dd9-4ddf-bc39-1e521fc5eec2"));});</script>

# %% [markdown]
# Next, to continue practicing, I am going to make a choropleth map of prison population by state.

# %%
#first we need to convert prison datatype to a int
sprison = dfe['Prison'].apply(lambda da: da.replace(',','')).astype(int)
dfe['Prison'] =sprison

# %%
dfe.head()
# Out:
#    Year  ICPSR State Code  Alphanumeric State Code       State  \
# 0  2012                41                        1     Alabama
# 1  2012                81                        2      Alaska
# 2  2012                61                        3     Arizona
# 3  2012                42                        4    Arkansas
# 4  2012                71                        5  California
#
#   VEP Total Ballots Counted VEP Highest Office VAP Highest Office  \
# 0                       NaN              58.6%              56.0%
# 1                     58.9%              58.7%              55.3%
# 2                     53.0%              52.6%              46.5%
# 3                     51.1%              50.7%              47.7%
# 4                     55.7%              55.1%              45.1%
#
#   Total Ballots Counted Highest Office Voting-Eligible Population (VEP)  \
# 0                   NaN      2,074,338                        3,539,217
# 1               301,694        300,495                          511,792
# 2             2,323,579      2,306,559                        4,387,900
# 3             1,078,548      1,069,468                        2,109,847
# 4            13,202,158     13,038,547                       23,681,837
#
#    Voting-Age Population (VAP) % Non-citizen  Prison Probation  Parole  \
# 0                    3707440.0          2.6%   32232    57,993   8,616
# 1                     543763.0          3.8%    5633     7,173   1,882
# 2                    4959270.0          9.9%   35188    72,452   7,460
# 3                    2242740.0          3.5%   14471    30,122  23,372
# 4                   28913129.0         17.4%  119455         0  89,287
#
#   Total Ineligible Felon State Abv
# 0                 71,584        AL
# 1                 11,317        AK
# 2                 81,048        AZ
# 3                 53,808        AR
# 4                208,742        CA

# %%
data = dict(type='choropleth',
           colorscale = 'Greens',
            reversescale = True,
           locations = dfe['State Abv'],
           locationmode = 'USA-states',
           z = dfe['Prison'],
           colorbar = {'title':'Number of People in Prison'}
           )

# %%
layout = dict(title = 'Number of People in Prison by State',
             geo = dict(scope = 'usa',
                       showlakes = True,
                       lakecolor = 'rgb(85,173,240)')
             )

# %%
choromap3 = go.Figure(data = [data], layout = layout)
iplot(choromap3)
# Out:
# <div id="21da98d8-a963-4c39-b68c-0b1cf2c8a2e8" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("21da98d8-a963-4c39-b68c-0b1cf2c8a2e8", [{"colorbar": {"title": "Number of People in Prison"}, "colorscale": "Greens", "locationmode": "USA-states", "locations": ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "District of Columbia", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"], "reversescale": true, "z": [32232, 5633, 35188, 14471, 119455, 18807, 16935, 6610, 0, 91954, 52737, 5544, 7985, 49348, 28266, 8470, 9346, 21863, 40047, 0, 20871, 10283, 43019, 9383, 22305, 30714, 3592, 4466, 12883, 2672, 21759, 6553, 49889, 35567, 1500, 50313, 25225, 13607, 50054, 3249, 21895, 3574, 28135, 157564, 6611, 0, 36425, 16355, 7052, 21987, 2163], "type": "choropleth", "uid": "a269a605-8c4a-4957-b8a7-50392d8c124c"}], {"geo": {"lakecolor": "rgb(85,173,240)", "scope": "usa", "showlakes": true}, "title": "Number of People in Prison by State"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("21da98d8-a963-4c39-b68c-0b1cf2c8a2e8"));});</script>

# %% [markdown]
# Noticing that this looks similar to the Voting Age Population, I'm interested in seeing what the distribution of non-citizens across the US is.

# %%
#Same as before, need to change the data type
snoncit = dfe['% Non-citizen'].apply(lambda da: float(da[:-1])/100)
dfe['% Non-citizen'] = snoncit

# %%
dfe.head()
# Out:
#    Year  ICPSR State Code  Alphanumeric State Code       State  \
# 0  2012                41                        1     Alabama
# 1  2012                81                        2      Alaska
# 2  2012                61                        3     Arizona
# 3  2012                42                        4    Arkansas
# 4  2012                71                        5  California
#
#   VEP Total Ballots Counted VEP Highest Office VAP Highest Office  \
# 0                       NaN              58.6%              56.0%
# 1                     58.9%              58.7%              55.3%
# 2                     53.0%              52.6%              46.5%
# 3                     51.1%              50.7%              47.7%
# 4                     55.7%              55.1%              45.1%
#
#   Total Ballots Counted Highest Office Voting-Eligible Population (VEP)  \
# 0                   NaN      2,074,338                        3,539,217
# 1               301,694        300,495                          511,792
# 2             2,323,579      2,306,559                        4,387,900
# 3             1,078,548      1,069,468                        2,109,847
# 4            13,202,158     13,038,547                       23,681,837
#
#    Voting-Age Population (VAP)  % Non-citizen  Prison Probation  Parole  \
# 0                    3707440.0          0.026   32232    57,993   8,616
# 1                     543763.0          0.038    5633     7,173   1,882
# 2                    4959270.0          0.099   35188    72,452   7,460
# 3                    2242740.0          0.035   14471    30,122  23,372
# 4                   28913129.0          0.174  119455         0  89,287
#
#   Total Ineligible Felon State Abv
# 0                 71,584        AL
# 1                 11,317        AK
# 2                 81,048        AZ
# 3                 53,808        AR
# 4                208,742        CA

# %% [markdown]
# Now that our data is in the right format, let's make a choropleth map.

# %%
data = dict(type='choropleth',
           colorscale = 'Blues',
            reversescale = True,
           locations = dfe['State Abv'],
           locationmode = 'USA-states',
           z = dfe['% Non-citizen'],
           colorbar = {'title':'% population not citizens'}
           )

# %%
layout = dict(title = 'Percent of Non-citizen Population by State',
             geo = dict(scope = 'usa',
                       showlakes = True,
                       lakecolor = 'rgb(85,173,240)')
             )

# %%
choromap4 = go.Figure(data = [data], layout = layout)
iplot(choromap4)
# Out:
# <div id="5aced021-350a-46f7-9f35-fab93283687c" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("5aced021-350a-46f7-9f35-fab93283687c", [{"colorbar": {"title": "% population not citizens"}, "colorscale": "Blues", "locationmode": "USA-states", "locations": ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "District of Columbia", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"], "reversescale": true, "z": [0.026000000000000002, 0.038, 0.099, 0.035, 0.174, 0.069, 0.085, 0.051, 0.09699999999999999, 0.10800000000000001, 0.07200000000000001, 0.092, 0.046, 0.08900000000000001, 0.036000000000000004, 0.032, 0.05, 0.022000000000000002, 0.027000000000000003, 0.018000000000000002, 0.08900000000000001, 0.084, 0.035, 0.044000000000000004, 0.015, 0.025, 0.009000000000000001, 0.047, 0.133, 0.03, 0.121, 0.073, 0.125, 0.061, 0.017, 0.022000000000000002, 0.045, 0.066, 0.033, 0.075, 0.035, 0.019, 0.033, 0.135, 0.07, 0.018000000000000002, 0.071, 0.08199999999999999, 0.008, 0.032, 0.025], "type": "choropleth", "uid": "cb8e1137-9cfe-46af-8695-c3551490013a"}], {"geo": {"lakecolor": "rgb(85,173,240)", "scope": "usa", "showlakes": true}, "title": "Percent of Non-citizen Population by State"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("5aced021-350a-46f7-9f35-fab93283687c"));});</script>

# %% [markdown]
# By comparing the previous 3 maps, we see that, while there are similarities in how they look, it doesn't appear that there are any obvious correlations between any of these three. Any similarities between these states could most likely be attributed to total population of each state, and would need to be validated by the addition of that data to this dataset in order to normalize the data.
